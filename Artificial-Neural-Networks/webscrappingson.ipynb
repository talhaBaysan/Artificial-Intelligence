# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings("ignore")

# %%
#Sütun adlarını tanımladıktan sonra integer olanları ayarlıyoruz
df = pd.DataFrame(columns=['İsim', 'Marka', 'İşlemci', 'İşlemci Çekirdeği', 'Ekran Çözünürlüğü', 'Ram', 'Bellek Türü', 'SSD', 'GPU Model', 'GPU Bellek', 'GPU Hız', 'Puan'])
df['İşlemci Çekirdeği'] = df['İşlemci Çekirdeği'].astype(int)
df['Ram'] = df['Ram'].astype(int)
df['SSD'] = df['SSD'].astype(int)
df['GPU Bellek'] = df['GPU Bellek'].astype(int)
df['GPU Hız'] = df['GPU Hız'].astype(int)
df['Puan'] = df['Puan'].astype(int)

# %%
#Verileri çekeceğimiz 217 url
url_listesi = ["https://www.epey.com/laptop/lenovo-thinkpad-p15-g2-20yqs2t902a9.html",
                "https://www.epey.com/laptop/asus-rog-zephyrus-g14-ga402xy-n2023w.html",
                "https://www.epey.com/laptop/msi-vector-gp77-13vg-015tr.html",
                "https://www.epey.com/laptop/lenovo-thinkpad-p17-g2-20yu001xtx047.html",
                "https://www.epey.com/laptop/hp-omen-17-cm2001nt-7p656ea.html",
                "https://www.epey.com/laptop/lenovo-thinkpad-p17-g2-20yu001xtx008.html",
                "https://www.epey.com/laptop/msi-titan-gt77-12uhs-037tr.html",
                "https://www.epey.com/laptop/asus-tuf-dash-f15-fx517zr-hn013a7.html",
                "https://www.epey.com/laptop/asus-proart-studiobook-pro-16-oled-w7600z3a-l2070.html",
                "https://www.epey.com/laptop/lenovo-thinkpad-p15-g2-20yqs2t902a6.html",
                "https://www.epey.com/laptop/msi-raider-ge78hx-13vh-037tr.html",
                "https://www.epey.com/laptop/asus-rog-strix-scar-18-g834jy-n6035.html",
                "https://www.epey.com/laptop/lenovo-thinkpad-p15-g2-20yqs2t902a3.html",
                "https://www.epey.com/laptop/asus-tuf-dash-f15-fx517zr-hn013a10.html",
                "https://www.epey.com/laptop/lenovo-legion-5-17-3-82jy007xtx10.html",
                "https://www.epey.com/laptop/lenovo-thinkpad-p16-21d60017tx07.html",
                "https://www.epey.com/laptop/asus-rog-strix-scar-18-g834jy-n6035w.html",
                "https://www.epey.com/laptop/lenovo-legion-pro-7-82wq0017tx.html",
                "https://www.epey.com/laptop/lenovo-legion-5-17-3-82jy007xtx08.html",
                "https://www.epey.com/laptop/asus-tuf-dash-f15-fx517zr-hn013a4.html",
                "https://www.epey.com/laptop/asus-rog-zephyrus-g15-ga503rm-hq123.html",
                "https://www.epey.com/laptop/lenovo-thinkpad-p15-g2-20yqs2t902a1.html",
                "https://www.epey.com/laptop/lenovo-legion-5-17-3-82jy007xtx05.html",
                "https://www.epey.com/laptop/msi-creator-z16hx-studio-b13vgto-044tr.html",
                "https://www.epey.com/laptop/lenovo-legion-pro-7-82wr000ntx.html",
                "https://www.epey.com/laptop/asus-tuf-dash-f15-fx517zr-hn013a2.html",
                "https://www.epey.com/laptop/msi-titan-gt77-12uhs-036tr.html",
                "https://www.epey.com/laptop/hp-victus-gaming-15-fa1039nt-vcs7p8l0ea24.html",
                "https://www.epey.com/laptop/lenovo-legion-5-17-3-82jy007xtx09.html",
                "https://www.epey.com/laptop/msi-raider-ge78hx-13vh-038tr.html",
                "https://www.epey.com/laptop/asus-rog-strix-g18-g814ji-n6108.html",
                "https://www.epey.com/laptop/msi-ge76-raider-12uhs-037tr.html",
                "https://www.epey.com/laptop/msi-raider-ge68-hx-13vg-059tr.html",
                "https://www.epey.com/laptop/msi-creator-z17-hx-studio-a13vgt-038tr.html",
                "https://www.epey.com/laptop/monster-abra-a5-v17-4-6.html",
                "https://www.epey.com/laptop/lenovo-thinkpad-p17-g2-20y
                "https://www.epey.com/laptop/casper-nirvana-c600-1165-8v00x-g-f.html",
                "https://www.epey.com/laptop/casper-nirvana-x500-1005-8u00x-g-f.html",
                "https://www.epey.com/laptop/asus-x515ja-ej2676.html",
                "https://www.epey.com/laptop/lenovo-v14-g2-82ka001ttx021.html",
                "https://www.epey.com/laptop/hp-probook-450-g8-2w8t0ea.html",
                "https://www.epey.com/laptop/lenovo-v14-g2-82ka001ttx061.html",
                "https://www.epey.com/laptop/hp-250-g7-175r5ea.html",
                "https://www.epey.com/laptop/dell-latitude-3301.html",
                "https://www.epey.com/laptop/casper-nirvana-x400-1021-8u00t-s.html"
                
                
                
                
               ]

# %%
#her bir url deki verilerin çekilmesi
for sayi in range(len(url_listesi)):
    print(sayi)
    url = url_listesi[sayi]
    print(url)
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36"}
    response = requests.get(url, headers=headers)
    # BeautifulSoup kullanarak HTML'i parse etme
    soup = BeautifulSoup(response.content, 'html.parser')

    title = soup.find('h1').text.strip()

    urun_ailesi_html = soup.find("strong", string="Ürün Ailesi").find_next_sibling("span").text
    urun_ailesi = urun_ailesi_html.strip().split()[0]

    islemci_modeli_html = soup.find("strong", string="İşlemci Modeli").find_next_sibling("span").text
    islemci_modeli = islemci_modeli_html.strip()

    #integer'a çeviriyoruz
    islemci_cekirdegi_html = soup.find("strong", string="İşlemci Çekirdeği").find_next_sibling("span").text
    islemci_cekirdegi = islemci_cekirdegi_html.strip().split()[0]
    islemci_cekirdegi = int(islemci_cekirdegi)

    ekran_cozunurlugu_html = soup.find("strong", string="Ekran Çözünürlüğü").find_next_sibling("span").text
    ekran_cozunurlugu = ekran_cozunurlugu_html.strip()

    bellek_html = soup.find("strong", string="Bellek (RAM)").find_next_sibling("span").text
    bellek = bellek_html.strip().split()[0]
    bellek = int(bellek)

    bellek_turu_html = soup.find("strong", string="Bellek Türü").find_next_sibling("span").text
    bellek_turu = bellek_turu_html.strip()

    #TB cinsinden ise GB'a çeviriyoruz,eğer ssd si yoksa 0 veriyoruz
    ssd_element = soup.find("strong", string="Sabit Disk (SSD) Boyutu")
    if ssd_element is not None:
        ssd_html = ssd_element.find_next_sibling("span").text
        ssd = ssd_html.strip().split()[0]
        ssd = float(ssd)
        if(ssd_html.strip().split()[1] == "TB"):
            ssd = ssd * 1024
        ssd = int(ssd)
    else:
        ssd = 0 

    #GPU yoksa "GPU" Yok yazdırıyoruz
    gpu_model_element = soup.find("strong", string="GPU Modeli")
    if gpu_model_element is not None:
        gpu_model_html = gpu_model_element.find_next_sibling("span").text
        gpu_model = gpu_model_html.strip()
    else:
        gpu_model = "GPU Yok"



    gpu_bellek_element = soup.find("strong", string="GPU Bellek Miktarı")
    if gpu_bellek_element is not None:
        gpu_bellek_html = gpu_bellek_element.find_next_sibling("span").text
        gpu_bellek = gpu_bellek_html.strip().split()[0]
        gpu_bellek = int(gpu_bellek)
    else:
        gpu_bellek = 0


    gpu_cekirdek_element = soup.find("strong", string="GPU Çekirdek Hızı")
    if gpu_cekirdek_element is not None:
        gpu_cekirdek_html = gpu_cekirdek_element.find_next_sibling("span").text
        gpu_cekirdek = gpu_cekirdek_html.strip().split()[0]
        gpu_cekirdek = int(gpu_cekirdek)
    else:
        gpu_cekirdek = 0



    div = soup.find('div', {'id': 'puan'}) 
    puan = div['data-text'] 

    #Tüm verileri dataframe'e atıyoruz
    df = df.append({'İsim': title,
                    'Marka': urun_ailesi,
                    'İşlemci': islemci_modeli,
                    'İşlemci Çekirdeği': islemci_cekirdegi,
                    'Ekran Çözünürlüğü': ekran_cozunurlugu,
                    'Ram': bellek,
                    'Bellek Türü': bellek_turu,
                    'SSD': ssd,
                    'GPU Model': gpu_model,
                    'GPU Bellek': gpu_bellek,
                    'GPU Hız': gpu_cekirdek,
                    'Puan': puan}, ignore_index=True)
# Out:
# 0
# https://www.epey.com/laptop/lenovo-thinkpad-p15-g2-20yqs2t902a9.html
# 1
# https://www.epey.com/laptop/asus-rog-zephyrus-g14-ga402xy-n2023w.html
# 2
# https://www.epey.com/laptop/msi-vector-gp77-13vg-015tr.html
# 3
# https://www.epey.com/laptop/lenovo-thinkpad-p17-g2-20yu001xtx047.html
# 4
# https://www.epey.com/laptop/hp-omen-17-cm2001nt-7p656ea.html
# 5
# https://www.epey.com/laptop/lenovo-thinkpad-p17-g2-20yu001xtx008.html
# 6
# https://www.epey.com/laptop/msi-titan-gt77-12uhs-037tr.html
# 7
# https://www.epey.com/laptop/asus-tuf-dash-f15-fx517zr-hn013a7.html
# 8
# https://www.epey.com/laptop/asus-proart-studiobook-pro-16-oled-w7600z3a-l2070.html
# 9
# https://www.epey.com/laptop/lenovo-thinkpad-p15-g2-20yqs2t902a6.html
# 10
# https://www.epey.com/laptop/msi-raider-ge78hx-13vh-037tr.html
# 11
# https://www.epey.com/laptop/asus-rog-strix-scar-18-g834jy-n6035.html
# 12
# https://www.epey.com/laptop/lenovo-thinkpad-p15-g2-20yqs2t902a3.html
# 13
# ...

# %%
#Türkçe karakterler için encode ederken cp1254 kullanıyoruz
df.to_csv('laptop_veriler.csv', index=False, encoding='cp1254', sep=';')

# %%
df
# Out:
#                                                İsim   Marka  \
# 0      Lenovo ThinkPad P15 G2 20YQS2T902A9 Notebook  Lenovo
# 1     Asus ROG Zephyrus G14 GA402XY-N2023W Notebook    Asus
# 2               MSI Vector GP77 13VG-015TR Notebook     MSI
# 3     Lenovo ThinkPad P17 G2 20YU001XTX047 Notebook  Lenovo
# 4            HP OMEN 17-cm2001nt (7P656EA) Notebook      HP
# ..                                              ...     ...
# 212            HP ProBook 450 G8 (2W8T0EA) Notebook      HP
# 213            Lenovo V14 G2 82KA001TTX061 Notebook  Lenovo
# 214                    HP 250 G7 (175R5EA) Notebook      HP
# 215  Dell Latitude 3301 N015L330113EMEA_W Ultrabook    Dell
# 216      Casper Nirvana X400.1021-8U00T-S Ultrabook  Casper
#
#                    İşlemci  İşlemci Çekirdeği   Ekran Çözünürlüğü  Ram  \
# 0     Intel Core i9-11950H                  8  1920 x 1080 Piksel  128
# 1       AMD Ryzen 9 7940HS                  8  2560 x 1600 Piksel   32
# ...
